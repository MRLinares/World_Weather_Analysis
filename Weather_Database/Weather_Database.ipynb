# %%
# Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations

latitude = np.random.uniform(-90, 90, size=2000)
longitude = np.random.uniform(-180, 180, size=2000)

latitude_longitude = zip(latitude, longitude)

latitude_longitude

# %%
coordinates = list(latitude_longitude)

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to cities list
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
cities
# Out:
# ['bluff',
#  'hervey bay',
#  'ambodifototra',
#  'new norfolk',
#  'narsaq',
#  'sentyabrskiy',
#  'tuktoyaktuk',
#  'rikitea',
#  'busselton',
#  'lorengau',
#  'lagoa',
#  'barrow',
#  'ushuaia',
#  'punta arenas',
#  'fairbanks',
#  'albany',
#  'novomikhaylovskiy',
#  'mahibadhoo',
#  'puerto ayora',
#  'hobart',
#  'qaanaaq',
#  'mataura',
#  'illoqqortoormiut',
#  'bardejov',
#  'hasaki',
#  'shchelyayur',
#  'cidreira',
#  'abha',
#  'saint-francois',
#  'vaini',
#  'port alfred',
#  'flinders',
#  'cabo san lucas',
#  'hami',
#  'port elizabeth',
#  'victoria',
#  'waipawa',
#  'hermanus',
#  'tuatapere',
#  'butaritari',
#  'aitape',
#  'dzhusaly',
#  'matara',
#  'east london',
#  'vaitupu',
#  'adamovka',
#  'pevek',
#  'shelburne',
#  'jimo',
#  'huron',
#  'clyde river',
#  'bacuit',
#  'beaverlodge',
#  'avarua',
#  'tsihombe',
#  'berlevag',
#  'ornskoldsvik',
#  'torbay',
#  'melilla',
#  'biltine',
#  'hay river',
#  'nome',
#  'castro',
#  'arraial do cabo',
#  'clonakilty',
#  'dikson',
#  'ruidoso',
#  'akureyri',
#  'houma',
#  'celestun',
#  'chapais',
#  'norwich',
#  'katsuura',
#  'dong hoi',
#  'tiarei',
#  'lere',
#  'suluq',
#  'potsdam',
#  'mookane',
#  'luau',
#  'lata',
#  'geraldton',
#  'muisne',
#  'pacific grove',
#  'nizwa',
#  'kota kinabalu',
#  'isangel',
#  'naze',
#  'beloha',
#  'georgetown',
#  'rio gallegos',
#  'yaan',
#  'mumford',
#  'muttupet',
#  'pitimbu',
#  'lima',
#  'walvis bay',
#  'aklavik',
#  'belushya guba',
#  'tezu',
#  'emerald',
#  'ribeira grande',
#  'todos santos',
#  'monterey',
#  'dandong',
#  'ust-maya',
#  'el dorado',
#  'nizhneyansk',
#  'la ronge',
#  'mjolby',
#  'assiniboia',
#  'verkhnevilyuysk',
#  'yellowknife',
#  'chokurdakh',
#  'mys shmidta',
#  'kulhudhuffushi',
#  'simbahan',
#  'norman wells',
#  'nabire',
#  'izberbash',
#  'samalaeulu',
#  'zhangye',
#  'atuona',
#  'labytnangi',
#  'tiksi',
#  'eldikan',
#  'riyadh',
#  'cape town',
#  'leningradskiy',
#  'russell',
#  'buchanan',
#  'codrington',
#  'puerto escondido',
#  'khorixas',
#  'nikolskoye',
#  'waingapu',
#  'kapaa',
#  'hilo',
#  'alofi',
#  'kyra',
#  'kansk',
#  'mount gambier',
#  'port hardy',
#  'bubaque',
#  'poronaysk',
#  'wulanhaote',
#  'richards bay',
#  'manado',
#  'bredasdorp',
#  'khatanga',
#  'saleaula',
#  'along',
#  'sungaipenuh',
#  'rawson',
#  'santa fe',
#  'kodiak',
#  'minas',
#  'itaituba',
#  'san-pedro',
#  'borovoy',
#  'trinidad',
#  'jamestown',
#  'fortuna',
#  'souillac',
#  'constitucion',
#  'stornoway',
#  'llanes',
#  'hithadhoo',
#  'nanortalik',
#  'taolanaro',
#  'karimganj',
#  'ancud',
#  'ituni',
#  'inverell',
#  'deputatskiy',
#  'mount isa',
#  'lebu',
#  'kailua',
#  'vao',
#  'sisimiut',
#  'mantua',
#  'kiama',
#  'asau',
#  'kutum',
#  'birjand',
#  'chicaman',
#  'cedar city',
#  'hongjiang',
#  'caravelas',
#  'coquimbo',
#  'ranir bazar',
#  'manono',
#  'lolua',
#  'cherskiy',
#  'tumannyy',
#  'lesnoy',
#  'darovskoy',
#  'port lincoln',
#  'vila velha',
#  'guerrero negro',
#  'young',
#  'tucumcari',
#  'robeasca',
#  'mahebourg',
#  'kavieng',
#  'thompson',
#  'saint-pierre',
#  'torremolinos',
#  'wanning',
#  'portland',
#  'jimenez',
#  'farafangana',
#  'nyurba',
#  'esperance',
#  'khonuu',
#  'upernavik',
#  'mar del plata',
#  'bathsheba',
#  'torit',
#  'saint-gaudens',
#  'sham churasi',
#  'baiyin',
#  'harper',
#  'tobol',
#  'palmas',
#  'oyo',
#  'faya',
#  'sao filipe',
#  'saint-philippe',
#  'whitehorse',
#  'tasiilaq',
#  'saskylakh',
#  'arroio grande',
#  'kurumkan',
#  'altus',
#  'yar-sale',
#  'ketchikan',
#  'kolokani',
#  'port blair',
#  'sao gabriel da cachoeira',
#  'sangar',
#  'saint george',
#  'malya',
#  'ponta do sol',
#  'alta floresta',
#  'amos',
#  'tyukhtet',
#  'yancheng',
#  'leshukonskoye',
#  'cap malheureux',
#  'alexandria',
#  'kruisfontein',
#  'hobyo',
#  'boguchany',
#  'okha',
#  'linchuan',
#  'bud',
#  'ilulissat',
#  'carnarvon',
#  'healesville',
#  'vanavara',
#  'camacha',
#  'kaeo',
#  'acari',
#  'touros',
#  'the valley',
#  'te anau',
#  'takhtamygda',
#  'cabatuan',
#  'itacarambi',
#  'dingle',
#  'mareeba',
#  'erice',
#  'pontianak',
#  'pechenga',
#  'komsomolskiy',
#  'santa rosa',
#  'ures',
#  'vardo',
#  'xining',
#  'gasa',
#  'moose factory',
#  'yulara',
#  'vossevangen',
#  'sumenep',
#  'brae',
#  'sangmelima',
#  'salalah',
#  'san luis',
#  'tianpeng',
#  'gamba',
#  'pangnirtung',
#  'presidencia roque saenz pena',
#  'normandin',
#  'santa maria',
#  'birnin kebbi',
#  'alhaurin de la torre',
#  'sibolga',
#  'zunyi',
#  'marijampole',
#  'saint-joseph',
#  'hovd',
#  'attawapiskat',
#  'arman',
#  'parainen',
#  'coahuayana',
#  'belyy yar',
#  'ola',
#  'lompoc',
#  'muyezerskiy',
#  'north platte',
#  'barcelona',
#  'tautira',
#  'darhan',
#  'sept-iles',
#  'basco',
#  'retsag',
#  'kaitangata',
#  'phan thiet',
#  'severo-kurilsk',
#  'tahoua',
#  'gheorgheni',
#  'churapcha',
#  'rungata',
#  'altamira',
#  'nanakuli',
#  'sola',
#  'san jeronimo',
#  'praia da vitoria',
#  'port-gentil',
#  'champasak',
#  'muhos',
#  'safaga',
#  'nokaneng',
#  'sao joao da barra',
#  'pedernales',
#  'palabuhanratu',
#  'pringsewu',
#  'zarasai',
#  'grand forks',
#  'makat',
#  'bonavista',
#  'kitimat',
#  'spineni',
#  'bengkulu',
#  'tanete',
#  'pingliang',
#  'amderma',
#  'leh',
#  'tocache',
#  'ambon',
#  'lalmohan',
#  'wamba',
#  'lisakovsk',
#  'mildura',
#  'sorland',
#  'kuytun',
#  'chuy',
#  'airai',
#  'kajaani',
#  'panguna',
#  'necochea',
#  'jutai',
#  'north bend',
#  'vammala',
#  'caibarien',
#  'zhigansk',
#  'saint-augustin',
#  'tessalit',
#  'ondorhaan',
#  'bay roberts',
#  'tawang',
#  'avallon',
#  'mackay',
#  'mercedes',
#  'orlik',
#  'meulaboh',
#  'kavaratti',
#  'pisco',
#  'alotau',
#  'makakilo city',
#  'ewing',
#  'osijek',
#  'namibe',
#  'ko samui',
#  'lavrentiya',
#  'ahuimanu',
#  'atar',
#  'olafsvik',
#  'bethel',
#  'chernyshevsk',
#  'amapa',
#  'oranjemund',
#  'grand river south east',
#  'ugoofaaru',
#  'fort-shevchenko',
#  'wajima',
#  'sinnamary',
#  'timizart',
#  'sitka',
#  'ballina',
#  'santiago del estero',
#  'broken hill',
#  'quatre cocos',
#  'rypefjord',
#  'sao francisco de assis',
#  'preobrazheniye',
#  'mogadishu',
#  'pilar',
#  'storsteinnes',
#  'daru',
#  'kamenskoye',
#  'vostok',
#  'barentsburg',
#  'pangai',
#  'inhambane',
#  'zeya',
#  'usinsk',
#  'marcona',
#  'seshcha',
#  'rocha',
#  'talnakh',
#  'long beach',
#  'adrar',
#  'dunedin',
#  'san juan',
#  'kieta',
#  'marawi',
#  'ermelo',
#  'jardim',
#  'provideniya',
#  'najran',
#  'san policarpo',
#  'cairns',
#  'acarau',
#  'lazurne',
#  'vestmannaeyjar',
#  'sampit',
#  'vanino',
#  'haines junction',
#  'chara',
#  'ostrovnoy',
#  'neiafu',
#  'kedougou',
#  'astoria',
#  'ruatoria',
#  'ishigaki',
#  'semme',
#  'hanna',
#  'taloda',
#  'hauterive',
#  'iacu',
#  'itajuba',
#  'haukipudas',
#  'yankton',
#  'finschhafen',
#  'ambilobe',
#  'sakaiminato',
#  'erdenet',
#  'toliary',
#  'yakeshi',
#  'santa lucia',
#  'karratha',
#  'coari',
#  'wasilla',
#  'cascais',
#  'doha',
#  'tshane',
#  'gorontalo',
#  'susangerd',
#  'uruzgan',
#  'vila',
#  'victor harbor',
#  'muros',
#  'bursa',
#  'mokhotlong',
#  'mindelo',
#  'fort saint john',
#  'havoysund',
#  'thanh hoa',
#  'maraba',
#  'louisbourg',
#  'pinawa',
#  'katangli',
#  'mafeteng',
#  'khromtau',
#  'tabialan',
#  'pyaozerskiy',
#  'husavik',
#  'concordia',
#  'the pas',
#  'karaton',
#  'hamilton',
#  'tuggurt',
#  'barawe',
#  'guymon',
#  'cabedelo',
#  'kristiinankaupunki',
#  'yarmolyntsi',
#  'ayni',
#  'jujuy',
#  'coolum beach',
#  'palmer',
#  'chopinzinho',
#  'cao bang',
#  'natchez',
#  'marshall',
#  'faanui',
#  'nueva germania',
#  'trat',
#  'penjamo',
#  'hofn',
#  'balykshi',
#  'olinda',
#  'tortosa',
#  'panaba',
#  'union',
#  'edson',
#  'turukhansk',
#  'saldanha',
#  'salinas',
#  'grand gaube',
#  'kinshasa',
#  'grand island',
#  'margate',
#  'vitina',
#  'lambarene',
#  'santa eulalia del rio',
#  'batagay-alyta',
#  'godhra',
#  'magadan',
#  'gardan diwal',
#  'castres',
#  'koumac',
#  'san giovanni rotondo',
#  'skjervoy',
#  'kimbe',
#  'keetmanshoop',
#  'pangody',
#  'beringovskiy',
#  'winnemucca',
#  'grindavik',
#  'padang',
#  'nantucket',
#  'gat',
#  'ust-tsilma',
#  'guanica',
#  'yerbogachen',
#  'tucuman',
#  'ndola',
#  'monrovia',
#  'antissa',
#  'kaniama',
#  'acapulco',
#  'san cristobal',
#  'viligili',
#  'choya',
#  'surab',
#  'samusu',
#  'marsa matruh',
#  'mitsamiouli',
#  'san jose',
#  'la plata',
#  'longlac',
#  'zahir pir',
#  'cooma',
#  'zastron',
#  'dzaoudzi',
#  'pochutla',
#  'arlit',
#  'sinkat',
#  'nyagan',
#  'moussoro',
#  'gravdal',
#  'jablah',
#  'loreto',
#  'florianopolis',
#  'hastings',
#  'panjab',
#  'martapura',
#  'kassala',
#  'burica',
#  'staroutkinsk',
#  'los llanos de aridane',
#  'moranbah',
#  'byron bay',
#  'anori',
#  'shimizu',
#  'maumere',
#  'tura',
#  'kilimatinde',
#  'ibra',
#  'ontario',
#  'mariental',
#  'tlahualilo',
#  'mollendo',
#  'gazanjyk',
#  'gongzhuling',
#  'luderitz',
#  'soyo',
#  'ilo',
#  'talcahuano',
#  'yanam',
#  'longyearbyen',
#  'mehamn',
#  'togur',
#  'puerto madryn',
#  'honiara',
#  'hambantota',
#  'sur',
#  'san onofre',
#  'touba',
#  'inuvik',
#  'taoudenni',
#  'blackfoot',
#  'benguela',
#  'mutsamudu',
#  'dzhuryn',
#  'sao gotardo',
#  'mutis',
#  'lichfield',
#  'kawana waters',
#  'champerico',
#  'nikel',
#  'lasa',
#  'avera',
#  'bac',
#  'luebo',
#  'grajewo',
#  'haikou',
#  'dolores',
#  'baruun-urt',
#  'praya',
#  'sobolevo',
#  'tortoli',
#  'bereda',
#  'nizhniy odes',
#  'dudinka',
#  'kahului',
#  'molochnoye',
#  'hailar',
#  'solnechnyy',
#  'merke',
#  'jian',
#  'santa barbara',
#  'maningrida',
#  'navsari',
#  'tungkang',
#  'el cobre',
#  'kemijarvi',
#  'sheridan',
#  'kez',
#  'paita',
#  'jumla',
#  'vallenar',
#  'aksha',
#  'handan',
#  'jefferson city',
#  'ishim',
#  'general roca',
#  'nilopolis',
#  'paamiut',
#  'bhopal',
#  'gaffney',
#  'japura',
#  'sataua',
#  'ozgon',
#  'santa rosalia',
#  'novomichurinsk',
#  'golden',
#  'lazaro cardenas',
#  'sorong',
#  'bulri',
#  'sabha',
#  'vikhorevka',
#  'burnie',
#  'warqla',
#  'aimores',
#  'san patricio',
#  'kargat',
#  'yumen',
#  'tallahassee',
#  'sfantu gheorghe',
#  'west memphis',
#  'bondo',
#  'okhotsk',
#  'feijo',
#  'sabang',
#  'naryan-mar',
#  'tabiauea',
#  'cilegon',
#  'tawkar',
#  'ust-ordynskiy',
#  'bolungarvik',
#  'kirakira',
#  'black forest',
#  'stepnyak',
#  'sung noen',
#  'bang khla',
#  'hammerfest',
#  'zuenoula',
#  'warmbad',
#  'ahipara',
#  'ubauro',
#  'fethiye',
#  'tarudant',
#  'hwange',
#  'ulaanbaatar',
#  'pemangkat',
#  'omboue',
#  'ishinomaki',
#  'lunel',
#  'van',
#  'eyl',
#  'horki',
#  'nizhnyaya pavlovka',
#  'navlya',
#  'funehiki',
#  'macamic',
#  'birao',
#  'nioro',
#  'hearst',
#  'te karaka',
#  'findochty',
#  'karpathos',
#  'vila franca do campo',
#  'iqaluit',
#  'shenjiamen',
#  'egvekinot',
#  'synya',
#  'umea',
#  'moosomin',
#  'moindou',
#  'emba',
#  'broome',
#  'mayor pablo lagerenza',
#  'seymchan',
#  'bajo baudo',
#  'zafra',
#  'dubrovytsya',
#  'mayo',
#  'huntington',
#  'gogrial',
#  'gandorhun',
#  'gwadar',
#  'labuan',
#  'camana',
#  'skelleftea',
#  'dindori',
#  'kurilsk',
#  'manokwari',
#  'srostki',
#  'atasu',
#  'lephepe',
#  'petropavlovsk-kamchatskiy',
#  'leander',
#  'campoverde',
#  'antofagasta',
#  'tripoli',
#  'lydenburg',
#  'vanimo',
#  'belmonte',
#  'kloulklubed',
#  'kralendijk',
#  'kusye-aleksandrovskiy',
#  'barcelos']

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.

record_count = 1
set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes (due to OpenWeatherMap API allowing 60 calls per min for free tier
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint URL with each city
    
    city_url = url + "&q=" + city.replace(" ", "+")
    
    
    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.

    try:

        # Parse the JSON and retrieve data.

        city_weather = requests.get(city_url).json()

    # Parse out the needed data.

        city_country = city_weather["sys"]["country"]
#         print(city_country)
        city_lat = city_weather["coord"]["lat"]

        city_lng = city_weather["coord"]["lon"]

        city_max_temp = city_weather["main"]["temp_max"]

        city_humidity = city_weather["main"]["humidity"]

        city_clouds = city_weather["clouds"]["all"]

        city_wind = city_weather["wind"]["speed"]

        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.

        city_data.append({"Country": city_country,
                          "City": city.title(),

                          "Lat": city_lat,

                          "Lng": city_lng,

                          "Max Temp": city_max_temp,

                          "Humidity": city_humidity,

                          "Cloudiness": city_clouds,

                          "Wind Speed": city_wind,

                          "Current Description": city_description})

# If an error is experienced, skip the city.

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
# print(city_url)
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | hervey bay
# Processing Record 3 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | narsaq
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | fairbanks
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | novomikhaylovskiy
# Processing Record 18 of Set 1 | mahibadhoo
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | bardejov
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | abha
# Processing Record 29 of Set 1 | saint-francois
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | flinders
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | hami
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | waipawa
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | aitape
# Processing Record 42 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 1 | matara
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | adamovka
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | shelburne
# Processing Record 49 of Set 1 | jimo
# Processing Record 50 of Set 1 | huron
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 2 | beaverlodge
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | berlevag
# Processing Record 7 of Set 2 | ornskoldsvik
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | melilla
# Processing Record 10 of Set 2 | biltine
# Processing Record 11 of Set 2 | hay river
# Processing Record 12 of Set 2 | nome
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | clonakilty
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | ruidoso
# Processing Record 18 of Set 2 | akureyri
# Processing Record 19 of Set 2 | houma
# Processing Record 20 of Set 2 | celestun
# Processing Record 21 of Set 2 | chapais
# Processing Record 22 of Set 2 | norwich
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | dong hoi
# Processing Record 25 of Set 2 | tiarei
# Processing Record 26 of Set 2 | lere
# Processing Record 27 of Set 2 | suluq
# Processing Record 28 of Set 2 | potsdam
# Processing Record 29 of Set 2 | mookane
# Processing Record 30 of Set 2 | luau
# Processing Record 31 of Set 2 | lata
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | muisne
# Processing Record 34 of Set 2 | pacific grove
# Processing Record 35 of Set 2 | nizwa
# Processing Record 36 of Set 2 | kota kinabalu
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | beloha
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | rio gallegos
# Processing Record 42 of Set 2 | yaan
# Processing Record 43 of Set 2 | mumford
# Processing Record 44 of Set 2 | muttupet
# Processing Record 45 of Set 2 | pitimbu
# Processing Record 46 of Set 2 | lima
# Processing Record 47 of Set 2 | walvis bay
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | tezu
# Processing Record 1 of Set 3 | emerald
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | todos santos
# Processing Record 4 of Set 3 | monterey
# Processing Record 5 of Set 3 | dandong
# Processing Record 6 of Set 3 | ust-maya
# Processing Record 7 of Set 3 | el dorado
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | la ronge
# Processing Record 10 of Set 3 | mjolby
# Processing Record 11 of Set 3 | assiniboia
# Processing Record 12 of Set 3 | verkhnevilyuysk
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | kulhudhuffushi
# Processing Record 17 of Set 3 | simbahan
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | nabire
# Processing Record 20 of Set 3 | izberbash
# Processing Record 21 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 3 | zhangye
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | labytnangi
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 3 | riyadh
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | russell
# Processing Record 31 of Set 3 | buchanan
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | puerto escondido
# Processing Record 34 of Set 3 | khorixas
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | waingapu
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | alofi
# Processing Record 40 of Set 3 | kyra
# Processing Record 41 of Set 3 | kansk
# Processing Record 42 of Set 3 | mount gambier
# Processing Record 43 of Set 3 | port hardy
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | poronaysk
# Processing Record 46 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 3 | richards bay
# Processing Record 48 of Set 3 | manado
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | along
# Processing Record 3 of Set 4 | sungaipenuh
# Processing Record 4 of Set 4 | rawson
# Processing Record 5 of Set 4 | santa fe
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | minas
# Processing Record 8 of Set 4 | itaituba
# Processing Record 9 of Set 4 | san-pedro
# Processing Record 10 of Set 4 | borovoy
# Processing Record 11 of Set 4 | trinidad
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | stornoway
# Processing Record 17 of Set 4 | llanes
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 4 | karimganj
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 4 | inverell
# Processing Record 25 of Set 4 | deputatskiy
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | kailua
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | sisimiut
# Processing Record 31 of Set 4 | mantua
# Processing Record 32 of Set 4 | kiama
# Processing Record 33 of Set 4 | asau
# Processing Record 34 of Set 4 | kutum
# Processing Record 35 of Set 4 | birjand
# Processing Record 36 of Set 4 | chicaman
# Processing Record 37 of Set 4 | cedar city
# Processing Record 38 of Set 4 | hongjiang
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | coquimbo
# Processing Record 41 of Set 4 | ranir bazar
# Processing Record 42 of Set 4 | manono
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 4 | cherskiy
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | lesnoy
# Processing Record 47 of Set 4 | darovskoy
# Processing Record 48 of Set 4 | port lincoln
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | young
# Processing Record 2 of Set 5 | tucumcari
# Processing Record 3 of Set 5 | robeasca
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | kavieng
# Processing Record 6 of Set 5 | thompson
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | torremolinos
# Processing Record 9 of Set 5 | wanning
# Processing Record 10 of Set 5 | portland
# Processing Record 11 of Set 5 | jimenez
# Processing Record 12 of Set 5 | farafangana
# Processing Record 13 of Set 5 | nyurba
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | mar del plata
# Processing Record 18 of Set 5 | bathsheba
# Processing Record 19 of Set 5 | torit
# Processing Record 20 of Set 5 | saint-gaudens
# Processing Record 21 of Set 5 | sham churasi
# Processing Record 22 of Set 5 | baiyin
# Processing Record 23 of Set 5 | harper
# Processing Record 24 of Set 5 | tobol
# Processing Record 25 of Set 5 | palmas
# Processing Record 26 of Set 5 | oyo
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | saint-philippe
# Processing Record 30 of Set 5 | whitehorse
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | arroio grande
# Processing Record 34 of Set 5 | kurumkan
# Processing Record 35 of Set 5 | altus
# Processing Record 36 of Set 5 | yar-sale
# Processing Record 37 of Set 5 | ketchikan
# Processing Record 38 of Set 5 | kolokani
# Processing Record 39 of Set 5 | port blair
# Processing Record 40 of Set 5 | sao gabriel da cachoeira
# Processing Record 41 of Set 5 | sangar
# Processing Record 42 of Set 5 | saint george
# Processing Record 43 of Set 5 | malya
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | alta floresta
# Processing Record 46 of Set 5 | amos
# Processing Record 47 of Set 5 | tyukhtet
# Processing Record 48 of Set 5 | yancheng
# Processing Record 49 of Set 5 | leshukonskoye
# Processing Record 50 of Set 5 | cap malheureux
# Processing Record 1 of Set 6 | alexandria
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | boguchany
# Processing Record 5 of Set 6 | okha
# Processing Record 6 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 6 | bud
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | carnarvon
# Processing Record 10 of Set 6 | healesville
# Processing Record 11 of Set 6 | vanavara
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | kaeo
# Processing Record 14 of Set 6 | acari
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | the valley
# Processing Record 17 of Set 6 | te anau
# Processing Record 18 of Set 6 | takhtamygda
# Processing Record 19 of Set 6 | cabatuan
# Processing Record 20 of Set 6 | itacarambi
# Processing Record 21 of Set 6 | dingle
# Processing Record 22 of Set 6 | mareeba
# Processing Record 23 of Set 6 | erice
# Processing Record 24 of Set 6 | pontianak
# Processing Record 25 of Set 6 | pechenga
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | santa rosa
# Processing Record 28 of Set 6 | ures
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | xining
# Processing Record 31 of Set 6 | gasa
# Processing Record 32 of Set 6 | moose factory
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | vossevangen
# Processing Record 35 of Set 6 | sumenep
# Processing Record 36 of Set 6 | brae
# Processing Record 37 of Set 6 | sangmelima
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | san luis
# Processing Record 40 of Set 6 | tianpeng
# Processing Record 41 of Set 6 | gamba
# Processing Record 42 of Set 6 | pangnirtung
# Processing Record 43 of Set 6 | presidencia roque saenz pena
# Processing Record 44 of Set 6 | normandin
# Processing Record 45 of Set 6 | santa maria
# Processing Record 46 of Set 6 | birnin kebbi
# Processing Record 47 of Set 6 | alhaurin de la torre
# Processing Record 48 of Set 6 | sibolga
# Processing Record 49 of Set 6 | zunyi
# Processing Record 50 of Set 6 | marijampole
# Processing Record 1 of Set 7 | saint-joseph
# Processing Record 2 of Set 7 | hovd
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | arman
# Processing Record 5 of Set 7 | parainen
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | belyy yar
# Processing Record 8 of Set 7 | ola
# Processing Record 9 of Set 7 | lompoc
# Processing Record 10 of Set 7 | muyezerskiy
# Processing Record 11 of Set 7 | north platte
# Processing Record 12 of Set 7 | barcelona
# Processing Record 13 of Set 7 | tautira
# Processing Record 14 of Set 7 | darhan
# Processing Record 15 of Set 7 | sept-iles
# Processing Record 16 of Set 7 | basco
# Processing Record 17 of Set 7 | retsag
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | phan thiet
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | tahoua
# Processing Record 22 of Set 7 | gheorgheni
# Processing Record 23 of Set 7 | churapcha
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | altamira
# Processing Record 26 of Set 7 | nanakuli
# Processing Record 27 of Set 7 | sola
# Processing Record 28 of Set 7 | san jeronimo
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | port-gentil
# Processing Record 31 of Set 7 | champasak
# Processing Record 32 of Set 7 | muhos
# Processing Record 33 of Set 7 | safaga
# Processing Record 34 of Set 7 | nokaneng
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | pedernales
# Processing Record 37 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 7 | pringsewu
# Processing Record 39 of Set 7 | zarasai
# Processing Record 40 of Set 7 | grand forks
# Processing Record 41 of Set 7 | makat
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | kitimat
# Processing Record 44 of Set 7 | spineni
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | tanete
# Processing Record 47 of Set 7 | pingliang
# Processing Record 48 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 7 | leh
# Processing Record 50 of Set 7 | tocache
# Processing Record 1 of Set 8 | ambon
# Processing Record 2 of Set 8 | lalmohan
# Processing Record 3 of Set 8 | wamba
# Processing Record 4 of Set 8 | lisakovsk
# Processing Record 5 of Set 8 | mildura
# Processing Record 6 of Set 8 | sorland
# Processing Record 7 of Set 8 | kuytun
# Processing Record 8 of Set 8 | chuy
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | kajaani
# Processing Record 11 of Set 8 | panguna
# Processing Record 12 of Set 8 | necochea
# Processing Record 13 of Set 8 | jutai
# Processing Record 14 of Set 8 | north bend
# Processing Record 15 of Set 8 | vammala
# Processing Record 16 of Set 8 | caibarien
# Processing Record 17 of Set 8 | zhigansk
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | tessalit
# Processing Record 20 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 8 | bay roberts
# Processing Record 22 of Set 8 | tawang
# Processing Record 23 of Set 8 | avallon
# Processing Record 24 of Set 8 | mackay
# Processing Record 25 of Set 8 | mercedes
# Processing Record 26 of Set 8 | orlik
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 8 | makakilo city
# Processing Record 32 of Set 8 | ewing
# Processing Record 33 of Set 8 | osijek
# Processing Record 34 of Set 8 | namibe
# Processing Record 35 of Set 8 | ko samui
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | ahuimanu
# Processing Record 38 of Set 8 | atar
# Processing Record 39 of Set 8 | olafsvik
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | chernyshevsk
# Processing Record 42 of Set 8 | amapa
# Processing Record 43 of Set 8 | oranjemund
# Processing Record 44 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | fort-shevchenko
# Processing Record 47 of Set 8 | wajima
# Processing Record 48 of Set 8 | sinnamary
# Processing Record 49 of Set 8 | timizart
# Processing Record 50 of Set 8 | sitka
# Processing Record 1 of Set 9 | ballina
# Processing Record 2 of Set 9 | santiago del estero
# Processing Record 3 of Set 9 | broken hill
# Processing Record 4 of Set 9 | quatre cocos
# Processing Record 5 of Set 9 | rypefjord
# Processing Record 6 of Set 9 | sao francisco de assis
# Processing Record 7 of Set 9 | preobrazheniye
# Processing Record 8 of Set 9 | mogadishu
# Processing Record 9 of Set 9 | pilar
# Processing Record 10 of Set 9 | storsteinnes
# Processing Record 11 of Set 9 | daru
# Processing Record 12 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 9 | pangai
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | zeya
# Processing Record 18 of Set 9 | usinsk
# Processing Record 19 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 9 | seshcha
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | long beach
# Processing Record 24 of Set 9 | adrar
# Processing Record 25 of Set 9 | dunedin
# Processing Record 26 of Set 9 | san juan
# Processing Record 27 of Set 9 | kieta
# Processing Record 28 of Set 9 | marawi
# Processing Record 29 of Set 9 | ermelo
# Processing Record 30 of Set 9 | jardim
# Processing Record 31 of Set 9 | provideniya
# Processing Record 32 of Set 9 | najran
# Processing Record 33 of Set 9 | san policarpo
# Processing Record 34 of Set 9 | cairns
# Processing Record 35 of Set 9 | acarau
# Processing Record 36 of Set 9 | lazurne
# Processing Record 37 of Set 9 | vestmannaeyjar
# Processing Record 38 of Set 9 | sampit
# Processing Record 39 of Set 9 | vanino
# Processing Record 40 of Set 9 | haines junction
# Processing Record 41 of Set 9 | chara
# Processing Record 42 of Set 9 | ostrovnoy
# Processing Record 43 of Set 9 | neiafu
# Processing Record 44 of Set 9 | kedougou
# Processing Record 45 of Set 9 | astoria
# Processing Record 46 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 9 | ishigaki
# Processing Record 48 of Set 9 | semme
# Processing Record 49 of Set 9 | hanna
# Processing Record 50 of Set 9 | taloda
# Processing Record 1 of Set 10 | hauterive
# Processing Record 2 of Set 10 | iacu
# Processing Record 3 of Set 10 | itajuba
# Processing Record 4 of Set 10 | haukipudas
# Processing Record 5 of Set 10 | yankton
# Processing Record 6 of Set 10 | finschhafen
# Processing Record 7 of Set 10 | ambilobe
# Processing Record 8 of Set 10 | sakaiminato
# Processing Record 9 of Set 10 | erdenet
# Processing Record 10 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 10 | yakeshi
# Processing Record 12 of Set 10 | santa lucia
# Processing Record 13 of Set 10 | karratha
# Processing Record 14 of Set 10 | coari
# Processing Record 15 of Set 10 | wasilla
# Processing Record 16 of Set 10 | cascais
# Processing Record 17 of Set 10 | doha
# Processing Record 18 of Set 10 | tshane
# Processing Record 19 of Set 10 | gorontalo
# Processing Record 20 of Set 10 | susangerd
# Processing Record 21 of Set 10 | uruzgan
# Processing Record 22 of Set 10 | vila
# Processing Record 23 of Set 10 | victor harbor
# Processing Record 24 of Set 10 | muros
# Processing Record 25 of Set 10 | bursa
# Processing Record 26 of Set 10 | mokhotlong
# Processing Record 27 of Set 10 | mindelo
# Processing Record 28 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | thanh hoa
# Processing Record 31 of Set 10 | maraba
# Processing Record 32 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 10 | pinawa
# Processing Record 34 of Set 10 | katangli
# Processing Record 35 of Set 10 | mafeteng
# Processing Record 36 of Set 10 | khromtau
# Processing Record 37 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 10 | pyaozerskiy
# Processing Record 39 of Set 10 | husavik
# Processing Record 40 of Set 10 | concordia
# Processing Record 41 of Set 10 | the pas
# Processing Record 42 of Set 10 | karaton
# Processing Record 43 of Set 10 | hamilton
# Processing Record 44 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 10 | guymon
# Processing Record 47 of Set 10 | cabedelo
# Processing Record 48 of Set 10 | kristiinankaupunki
# Processing Record 49 of Set 10 | yarmolyntsi
# Processing Record 50 of Set 10 | ayni
# Processing Record 1 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 11 | coolum beach
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | chopinzinho
# Processing Record 5 of Set 11 | cao bang
# Processing Record 6 of Set 11 | natchez
# Processing Record 7 of Set 11 | marshall
# Processing Record 8 of Set 11 | faanui
# Processing Record 9 of Set 11 | nueva germania
# Processing Record 10 of Set 11 | trat
# Processing Record 11 of Set 11 | penjamo
# Processing Record 12 of Set 11 | hofn
# Processing Record 13 of Set 11 | balykshi
# Processing Record 14 of Set 11 | olinda
# Processing Record 15 of Set 11 | tortosa
# Processing Record 16 of Set 11 | panaba
# Processing Record 17 of Set 11 | union
# Processing Record 18 of Set 11 | edson
# Processing Record 19 of Set 11 | turukhansk
# Processing Record 20 of Set 11 | saldanha
# Processing Record 21 of Set 11 | salinas
# Processing Record 22 of Set 11 | grand gaube
# Processing Record 23 of Set 11 | kinshasa
# Processing Record 24 of Set 11 | grand island
# Processing Record 25 of Set 11 | margate
# Processing Record 26 of Set 11 | vitina
# Processing Record 27 of Set 11 | lambarene
# Processing Record 28 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 11 | batagay-alyta
# Processing Record 30 of Set 11 | godhra
# Processing Record 31 of Set 11 | magadan
# Processing Record 32 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 33 of Set 11 | castres
# Processing Record 34 of Set 11 | koumac
# Processing Record 35 of Set 11 | san giovanni rotondo
# Processing Record 36 of Set 11 | skjervoy
# Processing Record 37 of Set 11 | kimbe
# Processing Record 38 of Set 11 | keetmanshoop
# Processing Record 39 of Set 11 | pangody
# Processing Record 40 of Set 11 | beringovskiy
# Processing Record 41 of Set 11 | winnemucca
# Processing Record 42 of Set 11 | grindavik
# Processing Record 43 of Set 11 | padang
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | gat
# Processing Record 46 of Set 11 | ust-tsilma
# Processing Record 47 of Set 11 | guanica
# Processing Record 48 of Set 11 | yerbogachen
# Processing Record 49 of Set 11 | tucuman
# Processing Record 50 of Set 11 | ndola
# Processing Record 1 of Set 12 | monrovia
# Processing Record 2 of Set 12 | antissa
# City not found. Skipping...
# Processing Record 3 of Set 12 | kaniama
# Processing Record 4 of Set 12 | acapulco
# Processing Record 5 of Set 12 | san cristobal
# Processing Record 6 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 12 | choya
# Processing Record 8 of Set 12 | surab
# Processing Record 9 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 12 | marsa matruh
# Processing Record 11 of Set 12 | mitsamiouli
# Processing Record 12 of Set 12 | san jose
# Processing Record 13 of Set 12 | la plata
# Processing Record 14 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 12 | zahir pir
# Processing Record 16 of Set 12 | cooma
# Processing Record 17 of Set 12 | zastron
# Processing Record 18 of Set 12 | dzaoudzi
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | arlit
# Processing Record 21 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 12 | nyagan
# Processing Record 23 of Set 12 | moussoro
# Processing Record 24 of Set 12 | gravdal
# Processing Record 25 of Set 12 | jablah
# Processing Record 26 of Set 12 | loreto
# Processing Record 27 of Set 12 | florianopolis
# Processing Record 28 of Set 12 | hastings
# Processing Record 29 of Set 12 | panjab
# Processing Record 30 of Set 12 | martapura
# Processing Record 31 of Set 12 | kassala
# Processing Record 32 of Set 12 | burica
# City not found. Skipping...
# Processing Record 33 of Set 12 | staroutkinsk
# Processing Record 34 of Set 12 | los llanos de aridane
# Processing Record 35 of Set 12 | moranbah
# Processing Record 36 of Set 12 | byron bay
# Processing Record 37 of Set 12 | anori
# Processing Record 38 of Set 12 | shimizu
# Processing Record 39 of Set 12 | maumere
# Processing Record 40 of Set 12 | tura
# Processing Record 41 of Set 12 | kilimatinde
# Processing Record 42 of Set 12 | ibra
# Processing Record 43 of Set 12 | ontario
# Processing Record 44 of Set 12 | mariental
# Processing Record 45 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 46 of Set 12 | mollendo
# Processing Record 47 of Set 12 | gazanjyk
# Processing Record 48 of Set 12 | gongzhuling
# Processing Record 49 of Set 12 | luderitz
# Processing Record 50 of Set 12 | soyo
# Processing Record 1 of Set 13 | ilo
# Processing Record 2 of Set 13 | talcahuano
# Processing Record 3 of Set 13 | yanam
# Processing Record 4 of Set 13 | longyearbyen
# Processing Record 5 of Set 13 | mehamn
# Processing Record 6 of Set 13 | togur
# Processing Record 7 of Set 13 | puerto madryn
# Processing Record 8 of Set 13 | honiara
# Processing Record 9 of Set 13 | hambantota
# Processing Record 10 of Set 13 | sur
# Processing Record 11 of Set 13 | san onofre
# Processing Record 12 of Set 13 | touba
# Processing Record 13 of Set 13 | inuvik
# Processing Record 14 of Set 13 | taoudenni
# Processing Record 15 of Set 13 | blackfoot
# Processing Record 16 of Set 13 | benguela
# Processing Record 17 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 13 | dzhuryn
# Processing Record 19 of Set 13 | sao gotardo
# Processing Record 20 of Set 13 | mutis
# Processing Record 21 of Set 13 | lichfield
# Processing Record 22 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 13 | champerico
# Processing Record 24 of Set 13 | nikel
# Processing Record 25 of Set 13 | lasa
# Processing Record 26 of Set 13 | avera
# Processing Record 27 of Set 13 | bac
# Processing Record 28 of Set 13 | luebo
# Processing Record 29 of Set 13 | grajewo
# Processing Record 30 of Set 13 | haikou
# Processing Record 31 of Set 13 | dolores
# Processing Record 32 of Set 13 | baruun-urt
# Processing Record 33 of Set 13 | praya
# Processing Record 34 of Set 13 | sobolevo
# Processing Record 35 of Set 13 | tortoli
# Processing Record 36 of Set 13 | bereda
# Processing Record 37 of Set 13 | nizhniy odes
# Processing Record 38 of Set 13 | dudinka
# Processing Record 39 of Set 13 | kahului
# Processing Record 40 of Set 13 | molochnoye
# Processing Record 41 of Set 13 | hailar
# Processing Record 42 of Set 13 | solnechnyy
# Processing Record 43 of Set 13 | merke
# Processing Record 44 of Set 13 | jian
# Processing Record 45 of Set 13 | santa barbara
# Processing Record 46 of Set 13 | maningrida
# Processing Record 47 of Set 13 | navsari
# Processing Record 48 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 13 | el cobre
# Processing Record 50 of Set 13 | kemijarvi
# Processing Record 1 of Set 14 | sheridan
# Processing Record 2 of Set 14 | kez
# Processing Record 3 of Set 14 | paita
# Processing Record 4 of Set 14 | jumla
# Processing Record 5 of Set 14 | vallenar
# Processing Record 6 of Set 14 | aksha
# Processing Record 7 of Set 14 | handan
# Processing Record 8 of Set 14 | jefferson city
# Processing Record 9 of Set 14 | ishim
# Processing Record 10 of Set 14 | general roca
# Processing Record 11 of Set 14 | nilopolis
# Processing Record 12 of Set 14 | paamiut
# Processing Record 13 of Set 14 | bhopal
# Processing Record 14 of Set 14 | gaffney
# Processing Record 15 of Set 14 | japura
# Processing Record 16 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 14 | santa rosalia
# Processing Record 19 of Set 14 | novomichurinsk
# Processing Record 20 of Set 14 | golden
# Processing Record 21 of Set 14 | lazaro cardenas
# Processing Record 22 of Set 14 | sorong
# Processing Record 23 of Set 14 | bulri
# Processing Record 24 of Set 14 | sabha
# Processing Record 25 of Set 14 | vikhorevka
# Processing Record 26 of Set 14 | burnie
# Processing Record 27 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 14 | aimores
# Processing Record 29 of Set 14 | san patricio
# Processing Record 30 of Set 14 | kargat
# Processing Record 31 of Set 14 | yumen
# Processing Record 32 of Set 14 | tallahassee
# Processing Record 33 of Set 14 | sfantu gheorghe
# Processing Record 34 of Set 14 | west memphis
# Processing Record 35 of Set 14 | bondo
# Processing Record 36 of Set 14 | okhotsk
# Processing Record 37 of Set 14 | feijo
# Processing Record 38 of Set 14 | sabang
# Processing Record 39 of Set 14 | naryan-mar
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | cilegon
# Processing Record 42 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 14 | ust-ordynskiy
# Processing Record 44 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 14 | kirakira
# Processing Record 46 of Set 14 | black forest
# Processing Record 47 of Set 14 | stepnyak
# Processing Record 48 of Set 14 | sung noen
# Processing Record 49 of Set 14 | bang khla
# Processing Record 50 of Set 14 | hammerfest
# Processing Record 1 of Set 15 | zuenoula
# Processing Record 2 of Set 15 | warmbad
# Processing Record 3 of Set 15 | ahipara
# Processing Record 4 of Set 15 | ubauro
# Processing Record 5 of Set 15 | fethiye
# Processing Record 6 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 15 | hwange
# Processing Record 8 of Set 15 | ulaanbaatar
# Processing Record 9 of Set 15 | pemangkat
# Processing Record 10 of Set 15 | omboue
# Processing Record 11 of Set 15 | ishinomaki
# Processing Record 12 of Set 15 | lunel
# Processing Record 13 of Set 15 | van
# Processing Record 14 of Set 15 | eyl
# Processing Record 15 of Set 15 | horki
# Processing Record 16 of Set 15 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 17 of Set 15 | navlya
# Processing Record 18 of Set 15 | funehiki
# Processing Record 19 of Set 15 | macamic
# Processing Record 20 of Set 15 | birao
# Processing Record 21 of Set 15 | nioro
# Processing Record 22 of Set 15 | hearst
# Processing Record 23 of Set 15 | te karaka
# Processing Record 24 of Set 15 | findochty
# Processing Record 25 of Set 15 | karpathos
# Processing Record 26 of Set 15 | vila franca do campo
# Processing Record 27 of Set 15 | iqaluit
# Processing Record 28 of Set 15 | shenjiamen
# Processing Record 29 of Set 15 | egvekinot
# Processing Record 30 of Set 15 | synya
# Processing Record 31 of Set 15 | umea
# Processing Record 32 of Set 15 | moosomin
# Processing Record 33 of Set 15 | moindou
# Processing Record 34 of Set 15 | emba
# Processing Record 35 of Set 15 | broome
# Processing Record 36 of Set 15 | mayor pablo lagerenza
# Processing Record 37 of Set 15 | seymchan
# Processing Record 38 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 39 of Set 15 | zafra
# Processing Record 40 of Set 15 | dubrovytsya
# Processing Record 41 of Set 15 | mayo
# Processing Record 42 of Set 15 | huntington
# Processing Record 43 of Set 15 | gogrial
# Processing Record 44 of Set 15 | gandorhun
# Processing Record 45 of Set 15 | gwadar
# Processing Record 46 of Set 15 | labuan
# Processing Record 47 of Set 15 | camana
# Processing Record 48 of Set 15 | skelleftea
# Processing Record 49 of Set 15 | dindori
# Processing Record 50 of Set 15 | kurilsk
# Processing Record 1 of Set 16 | manokwari
# Processing Record 2 of Set 16 | srostki
# Processing Record 3 of Set 16 | atasu
# Processing Record 4 of Set 16 | lephepe
# City not found. Skipping...
# Processing Record 5 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 16 | leander
# Processing Record 7 of Set 16 | campoverde
# Processing Record 8 of Set 16 | antofagasta
# Processing Record 9 of Set 16 | tripoli
# Processing Record 10 of Set 16 | lydenburg
# Processing Record 11 of Set 16 | vanimo
# Processing Record 12 of Set 16 | belmonte
# Processing Record 13 of Set 16 | kloulklubed
# Processing Record 14 of Set 16 | kralendijk
# Processing Record 15 of Set 16 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 16 of Set 16 | barcelos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bluff      NZ -46.6000  168.3333     57.79        79          20
# 1   Hervey Bay      AU -25.2986  152.8535     71.02        77          66
# 2  New Norfolk      AU -42.7826  147.0587     54.72        62         100
# 3       Narsaq      GL  60.9167  -46.0500     41.61        57          74
# 4  Tuktoyaktuk      CA  69.4541 -133.0374     64.40        55          75
#
#    Wind Speed Current Description
# 0        6.62          few clouds
# 1        5.01       broken clouds
# 2        1.01     overcast clouds
# 3        6.22       broken clouds
# 4       10.36       broken clouds

# %%
# Create the output file(CSV)

output_data_file = "WeatherPy_Data/WeatherPy_Database.csv"

# Export the City_Data into a csv

city_data_df.to_csv(output_data_file, index_label="City_ID")
